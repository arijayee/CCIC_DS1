# %%
##Political Party matrix
PoliticalP = [["Demorcat","Democrat"],
             ["Rebulican","Republican"],
             ["Socialism"],
             ["none"],
             ["Not interested","Not Interested","Not Interested","Not Interested"]]

#Music Genre Matrix
MusicG = [["Indie","Indie"],
          ["RnB"],
          ["Hip hop","Hip hop","Hip hop"],
          ["Rap","Rap","Rap"],
          ["Thrash Metal"],
          ["Classical"],
          ["All"]]

#Siblings Matrix
Siblings = [ [1,1,1],
           [2,2,2,2,2],
           [0,0],[3],[7]]

#Birth Month Matrix 
BMonth = [["June","June","January"],
         ["January","May","May"],
         ["February","July","September"],
         ["November","March","N/A"]]
         

#Grade Matrix
Grade = [[12,12,12,12,12,12],
        [10,10],
        [11,11,11,11]]
i=0
print("January: ", end='')

for i in range(0, len(BMonth)):
    for j in range(0, len(BMonth[0])-1):
        if BMonth[i][j]=="January":
            
            print("*")

print("Februray: ", end='')            

for i in range(0, len(BMonth)):
    for j in range(0, len(BMonth[0])-1):
        if BMonth[i][j]=="February":
            
            print("*")
print("March: ", end='')

for i in range(0, len(BMonth)):
    for j in range(0, len(BMonth[0])-1):
        if BMonth[i][j]=="March":
            
            print("*")
            
print("May: ", end='')

for i in range(0, len(BMonth)):
    for j in range(0, len(BMonth[0])-1):
        if BMonth[i][j]=="May":
            
            print("*") 
print("June: ", end='')

for i in range(0, len(BMonth)):
    for j in range(0, len(BMonth[0])-1):
        if BMonth[i][j]=="June":
            
            print("*")

print("July: ", end='')

for i in range(0, len(BMonth)):
    for j in range(0, len(BMonth[0])-1):
        if BMonth[i][j]=="July":
            
            print("*")


print("September: ", end='')

for i in range(0, len(BMonth)):
    for j in range(0, len(BMonth[0])-1):
        if BMonth[i][j]=="September":
            
            print("*")

print("November: ", end='')

for i in range(0, len(BMonth)):
    for j in range(0, len(BMonth[0])-1):
        if BMonth[i][j]=="November":
            
            print("*")
# Out:
# January: *
# Februray: *
# March: *
# May: *
# June: *
# *
# July: *
# September: November: *
